# %% [markdown]
# <a href="https://colab.research.google.com/github/rko7/Kaggle_ML-Project/blob/main/Machine_Learning_Project_Diabetes_Prediction_using_Machine_Learning_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Analysis <br>
# PIMA Diabetes Datasets

# %%
# load the diabetes dataset to pandas dataframe
df = pd.read_csv('/content/diabetes.csv')

# %%
# print the first 5 rows
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# number of rows & columns
df.shape
# Out:
# (768, 9)

# %%
# get the statistical measures of the data
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# Correlation Matrix of all the Features
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(),annot =True,fmt = '0.2f')
# Out:
# <Axes: >

# %%
# distribution of BMI
plt.figure(figsize=(10, 6))
sns.histplot(df['BMI'], kde=True, bins=10)
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %%
# distribution of Blood Pressure
plt.figure(figsize=(10, 6))
sns.histplot(df['BloodPressure'], kde=True, bins=10)
plt.xlabel('Blood Pressure')
plt.ylabel('Frequency')
plt.show()

# %%
# relationship between Age and BMI
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Age', y='BMI', hue='Outcome', palette='Set1', s=100)
plt.xlabel('Age')
plt.ylabel('BMI')
plt.legend(title='Outcome', labels=['Non-Diabetic', 'Diabetic'])
plt.show()

# %%
# distribution of Insulin Levels by Outcome
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Outcome', y='Insulin', palette='Set1')
plt.xlabel('Outcome')
plt.ylabel('Insulin')
plt.xticks([0, 1], ['Non-Diabetic', 'Diabetic'])
plt.show()

# %%
# Pregnancies vs. Outcome
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Outcome', y='Pregnancies', palette='Set1')
plt.xlabel('Outcome')
plt.ylabel('Number of Pregnancies')
plt.xticks([0, 1], ['Non-Diabetic', 'Diabetic'])
plt.show()

# %%
# Blood Pressure vs. Outcome
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Outcome', y='BloodPressure', palette='Set1')
plt.xlabel('Outcome')
plt.ylabel('Blood Pressure')
plt.xticks([0, 1], ['Non-Diabetic', 'Diabetic'])
plt.show()

# %%
# relationship between BMI, Insulin, and Diabetes Outcome
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='BMI', y='Insulin', hue='Outcome', palette='Set1', s=100)
plt.xlabel('BMI')
plt.ylabel('Insulin')
plt.legend(title='Outcome', labels=['Non-Diabetic', 'Diabetic'])
plt.show()

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# 0 means Non-Diabetic<br>
# 1 means Diabetic

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
# separate the data & labels
X = df.drop(columns = 'Outcome', axis = 1)
Y = df['Outcome']

# %%
print(X)
print(Y)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %% [markdown]
# Data Standardization

# %%
scaler = StandardScaler()
scaler.fit(X)
std_data = scaler.transform(X)

# %%
print(std_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X = std_data
Y = df['Outcome']

# %%
print(X)
print(Y)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Train Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# Training the Model

# %%
classifier = svm.SVC(kernel='linear')

# %%
# train the support vector Machine Classifier
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy score on the training data
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy Score of the Training Data : ', training_data_accuracy)
# Out:
# Accuracy Score of the Training Data :  0.7866449511400652

# %%
# accuracy score on the testing data
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy Score of the Test Data : ', test_data_accuracy)
# Out:
# Accuracy Score of the Test Data :  0.7727272727272727

# %% [markdown]
# Making a Predictive System

# %%
input_data = (2, 126, 84, 21, 0, 29.6, 176, 32)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# standardize the input data
std_data = scaler.transform(input_data_reshaped)
print(std_data)

prediction = classifier.predict(std_data)
print(prediction)

if (prediction[0] == 0):
    print('The person is Non-Diabetic')
else:
    print('The person is Diabetic')
# Out:
# [[-5.47918591e-01  1.59786597e-01  7.70013751e-01  2.90770700e-02
#   -6.92890572e-01 -3.03664210e-01  5.30115765e+02 -1.05584152e-01]]
# [1]
# The person is Diabetic
